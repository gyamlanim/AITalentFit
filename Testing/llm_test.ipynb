# %%
# Test using the CustomLLM class that's properly configured for your Azure AI endpoint
import sys
import os

# Add the parent directory to Python path to find our custom modules
parent_dir = os.path.dirname(os.getcwd())
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from llm_interface import CustomLLM

try:
    # Create an instance of your custom LLM
    llm = CustomLLM()
    
    # Test the chat completion
    prompt = "I am going to Paris, what should I see?"
    response = llm.get_chat_completion(prompt, agent_name="travel assistant")
    
    print("Response:", response)
    
except Exception as e:
    print(f"Error: {e}")
    print("Make sure you're authenticated with Azure CLI: az login")
# Out:
# Response: Paris is a city filled with iconic landmarks, rich history, and incredible art, so there’s no shortage of amazing places to see and experiences to enjoy. Here's a list of must-see attractions and activities in Paris:
#
# ### **Iconic Landmarks**
# 1. **Eiffel Tower**
#    - No trip to Paris is complete without visiting the Eiffel Tower. You can admire it from the Champ de Mars or climb to the top for incredible views of the city.
#
# 2. **Louvre Museum**
#    - Home to the famous *Mona Lisa* and countless masterpieces, this world-renowned museum is a must for art and history lovers.
#
# 3. **Notre-Dame Cathedral**
#    - Although under restoration, this Gothic masterpiece is still worth visiting for its stunning architecture and historical significance.
#
# 4. **Sacré-Cœur Basilica**
#    - Located in Montmartre, this white-domed church offers breathtaking views of Paris from its steps.
#
# 5. **Arc de Triomphe**
# ...
