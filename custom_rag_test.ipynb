# %%
from custom_rag import CustomRAG

# %%
rag_object = CustomRAG(db_path="resume_db", table_name="resume_table")
# Out:
# Using ChromaDB for vector similarity search

# %%
rag_object.enter_resume_to_db(file_path="data/sample_resumes/ArjunResume-AIGEN.pdf")
# Out:
# 'Resume stored successfully'

# %%
rag_object.evaluate_top_resumes("Looking for a software engineer with experience in AI and machine learning.", 5)
# Out:
# [{'name': 'Arjun Mehta',
#   'email': 'arjun.meh@gmail.com',
#   'phone': '(555) 123-4567',
#   'resume_id': 1,
#   'candidate_id': '1a02ce68-cd93-462b-9b91-b7ac2580797b',
#   'similarity_score': 0.5862257778644562,
#   'evaluation': {'total_weighted_score': 32.4,
#    'recommendation': 'Reject',
#    'criteria_scores': [{'criterion': 'Proficiency in Python, TensorFlow, PyTorch, or other ML frameworks',
#      'score': 2,
#      'weight': 15,
#      'weighted_score': 0.3,
#      'evidence': 'Proficient in Python but no mention of TensorFlow, PyTorch, or other ML frameworks.'},
#     {'criterion': 'Experience with telecom-specific AI/ML applications',
#      'score': 0,
#      'weight': 15,
#      'weighted_score': 0,
#      'evidence': 'No evidence of AI/ML applications specific to telecom.'},
#     {'criterion': 'Hands-on experience with cloud-native platforms (e.g., Kubernetes, Docker)',
#      'score': 8,
#      'weight': 12,
#      'weighted_score': 0.96,
# ...
