# %%
from vector_db import VectorDB

# %%
db = VectorDB(db_location="resume_db")
# Out:
# Using ChromaDB for vector similarity search

# %%
db.create_table("resume_table")

# %%
db.insert_row("resume_table", 
              summary="Software Engineer with 5 years of experience", 
              full_resume="Full resume text here", 
              email="candidate@example.com", 
              phone="123-456-7890", 
              name="John Doe")

# %%
db.retrieve_top_results("resume_table", 5, "Arjun")
# Out:
# [{'rank': 1,
#   'candidate_id': '56f2a1a7-ee6e-45ef-8d9d-95e1e040058a',
# ...
